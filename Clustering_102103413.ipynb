# %%
# !pip install pycaret &> /dev/null
print ("Pycaret installed sucessfully!!")
# Out:
# Pycaret installed sucessfully!!

# %%
from pycaret.datasets import get_data
dataSets = get_data('index')
# Out:
#                              Dataset    Data Types  \
# 0                            anomaly  Multivariate
# 1                             france  Multivariate
# 2                            germany  Multivariate
# 3                               bank  Multivariate
# 4                              blood  Multivariate
# 5                             cancer  Multivariate
# 6                             credit  Multivariate
# 7                           diabetes  Multivariate
# 8                    electrical_grid  Multivariate
# 9                           employee  Multivariate
# 10                             heart  Multivariate
# 11                     heart_disease  Multivariate
# 12                         hepatitis  Multivariate
# 13                            income  Multivariate
# 14                             juice  Multivariate
# 15                               nba  Multivariate
# 16                              wine  Multivariate
# ...

# %%
cancer = get_data("cancer")
# Out:
#    Class  age  menopause  tumor-size  inv-nodes  node-caps  deg-malig  breast  \
# 0      0    5          1           1          1          2          1       3
# 1      0    5          4           4          5          7         10       3
# 2      0    3          1           1          1          2          2       3
# 3      0    6          8           8          1          3          4       3
# 4      0    4          1           1          3          2          1       3
#
#    breast-quad  irradiat
# 0            1         1
# 1            2         1
# 2            1         1
# 3            7         1
# 4            1         1

# %%
cancer.tail()
# Out:
#      Class  age  menopause  tumor-size  inv-nodes  node-caps  deg-malig  \
# 678      0    3          1           1          1          3          2
# 679      0    2          1           1          1          2          1
# 680      1    5         10          10          3          7          3
# 681      1    4          8           6          4          3          4
# 682      1    4          8           8          5          4          5
#
#      breast  breast-quad  irradiat
# 678       1            1         1
# 679       1            1         1
# 680       8           10         2
# 681      10            6         1
# 682      10            4         1

# %%
from pycaret.clustering import *
import pandas as pd
kMeanClusteringParameters = setup(cancer, verbose=False)
KMeanClusteringModel = create_model('kmeans', num_clusters=4)
# Out:
# <style type="text/css">
# </style>
# <table id="T_b5ce4" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b5ce4_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_b5ce4_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_b5ce4_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_b5ce4_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_b5ce4_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_b5ce4_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b5ce4_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_b5ce4_row0_col0" class="data row0 col0" >0.5362</td>
#       <td id="T_b5ce4_row0_col1" class="data row0 col1" >519.1590</td>
# ...

# %%
from pycaret.datasets import get_data
from pycaret.clustering import *

cancer = get_data('cancer', verbose=False)
setup(data = cancer, verbose=False)

print("For Cluster = 3")
x = create_model('kmeans', num_clusters = 3)

print("For Cluster = 4")
x = create_model('kmeans', num_clusters = 4)

print("For Cluster = 5")
x = create_model('kmeans', num_clusters = 5)
# Out:
# For Cluster = 3
# <style type="text/css">
# </style>
# <table id="T_f2eda" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f2eda_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_f2eda_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_f2eda_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_f2eda_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_f2eda_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_f2eda_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f2eda_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_f2eda_row0_col0" class="data row0 col0" >0.5250</td>
#       <td id="T_f2eda_row0_col1" class="data row0 col1" >675.3120</td>
# ...

# %%
from pycaret.datasets import get_data
from pycaret.clustering import *
import pandas as pd
from sklearn.metrics import silhouette_score
from sklearn.metrics import calinski_harabasz_score
from sklearn.metrics import davies_bouldin_score

# Load the dataset
cancer = get_data('cancer', verbose=False)

# Setup the environment
setup(data=cancer, verbose=False)

# Initialize an empty DataFrame to store the silhouette scores
no_pre = pd.DataFrame(columns=['Num Clusters', 'Silhouette Score'])

# Iterate over different numbers of clusters
for num_clusters in [3, 4, 5]:
    print(f"For Cluster = {num_clusters}")

    # Create the KMeans clustering model
    kmeans_model = create_model('kmeans', num_clusters=num_clusters)

    # Get cluster labels
    labels = kmeans_model.labels_

    # Compute silhouette score
    silhouette_score_value = silhouette_score(cancer, labels)
    calinski_harabasz_score_value = calinski_harabasz_score(cancer, labels)
    davies_bouldin_score_value=davies_bouldin_score(cancer,labels)
    # Store the silhouette score in the DataFrame
    no_pre = no_pre.append({'Num Clusters': num_clusters, 'Silhouette Score': silhouette_score_value, 'Calinski-Score':calinski_harabasz_score_value,'Davies-Bouldin':davies_bouldin_score_value}, ignore_index=True)
    new_no_pre=no_pre.set_index('Num Clusters')
# Print the silhouette scores DataFrame
print(new_no_pre)
# Out:
# For Cluster = 3
# <style type="text/css">
# </style>
# <table id="T_5452d" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5452d_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_5452d_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_5452d_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_5452d_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_5452d_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_5452d_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5452d_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_5452d_row0_col0" class="data row0 col0" >0.5261</td>
#       <td id="T_5452d_row0_col1" class="data row0 col1" >675.2850</td>
# ...

# %%
from pycaret.datasets import get_data
from pycaret.clustering import *
import pandas as pd
from sklearn.metrics import silhouette_score
from sklearn.metrics import calinski_harabasz_score
from sklearn.metrics import davies_bouldin_score

# Load the dataset
cancer = get_data('cancer', verbose=False)

# Setup the environment
setup(data=cancer,normalize = True, normalize_method = 'zscore', verbose=False)

# Initialize an empty DataFrame to store the silhouette scores
normal = pd.DataFrame(columns=['Num Clusters', 'Silhouette Score'])

# Iterate over different numbers of clusters
for num_clusters in [3, 4, 5]:
    print(f"For Cluster = {num_clusters}")

    # Create the KMeans clustering model
    kmeans_model = create_model('kmeans', num_clusters=num_clusters)

    # Get cluster labels
    labels = kmeans_model.labels_

    # Compute silhouette score
    silhouette_score_value = silhouette_score(cancer, labels)
    calinski_harabasz_score_value = calinski_harabasz_score(cancer, labels)
    davies_bouldin_score_value=davies_bouldin_score(cancer,labels)
    # Store the silhouette score in the DataFrame
    normal = normal.append({'Num Clusters': num_clusters, 'Silhouette Score': silhouette_score_value, 'Calinski-Score':calinski_harabasz_score_value,'Davies-Bouldin':davies_bouldin_score_value}, ignore_index=True)
    new_normal=normal.set_index('Num Clusters')
# Print the silhouette scores DataFrame
print(new_normal)
# Out:
# For Cluster = 3
# <style type="text/css">
# </style>
# <table id="T_fb42c" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_fb42c_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_fb42c_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_fb42c_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_fb42c_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_fb42c_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_fb42c_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_fb42c_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_fb42c_row0_col0" class="data row0 col0" >0.5756</td>
#       <td id="T_fb42c_row0_col1" class="data row0 col1" >663.3644</td>
# ...

# %%
from pycaret.datasets import get_data
from pycaret.clustering import *
import pandas as pd
from sklearn.metrics import silhouette_score
from sklearn.metrics import calinski_harabasz_score
from sklearn.metrics import davies_bouldin_score

# Load the dataset
cancer = get_data('cancer', verbose=False)

# Setup the environment
setup(data=cancer,transformation = True, transformation_method = 'yeo-johnson', verbose=False)

# Initialize an empty DataFrame to store the silhouette scores
transform = pd.DataFrame(columns=['Num Clusters', 'Silhouette Score'])

# Iterate over different numbers of clusters
for num_clusters in [3, 4, 5]:
    print(f"For Cluster = {num_clusters}")

    # Create the KMeans clustering model
    kmeans_model = create_model('kmeans', num_clusters=num_clusters)

    # Get cluster labels
    labels = kmeans_model.labels_

    # Compute silhouette score
    silhouette_score_value = silhouette_score(cancer, labels)
    calinski_harabasz_score_value = calinski_harabasz_score(cancer, labels)
    davies_bouldin_score_value=davies_bouldin_score(cancer,labels)
    # Store the silhouette score in the DataFrame
    transform = transform.append({'Num Clusters': num_clusters, 'Silhouette Score': silhouette_score_value, 'Calinski-Score':calinski_harabasz_score_value,'Davies-Bouldin':davies_bouldin_score_value}, ignore_index=True)
    new_transform=transform.set_index('Num Clusters')
# Print the silhouette scores DataFrame
print(new_transform)
# Out:
# For Cluster = 3
# <style type="text/css">
# </style>
# <table id="T_bd43f" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_bd43f_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_bd43f_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_bd43f_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_bd43f_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_bd43f_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_bd43f_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_bd43f_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_bd43f_row0_col0" class="data row0 col0" >0.4833</td>
#       <td id="T_bd43f_row0_col1" class="data row0 col1" >1224.8647</td>
# ...

# %%
from pycaret.datasets import get_data
from pycaret.clustering import *
import pandas as pd
from sklearn.metrics import silhouette_score
from sklearn.metrics import calinski_harabasz_score
from sklearn.metrics import davies_bouldin_score

# Load the dataset
cancer = get_data('cancer', verbose=False)

# Setup the environment
setup(data=cancer,pca = True, pca_method = 'linear', verbose=False)

# Initialize an empty DataFrame to store the silhouette scores
pca = pd.DataFrame(columns=['Num Clusters', 'Silhouette Score'])

# Iterate over different numbers of clusters
for num_clusters in [3, 4, 5]:
    print(f"For Cluster = {num_clusters}")

    # Create the KMeans clustering model
    kmeans_model = create_model('kmeans', num_clusters=num_clusters)

    # Get cluster labels
    labels = kmeans_model.labels_

    # Compute silhouette score
    silhouette_score_value = silhouette_score(cancer, labels)
    calinski_harabasz_score_value = calinski_harabasz_score(cancer, labels)
    davies_bouldin_score_value=davies_bouldin_score(cancer,labels)
    # Store the silhouette score in the DataFrame
    pca = pca.append({'Num Clusters': num_clusters, 'Silhouette Score': silhouette_score_value, 'Calinski-Score':calinski_harabasz_score_value,'Davies-Bouldin':davies_bouldin_score_value}, ignore_index=True)
    new_pca=pca.set_index('Num Clusters')
# Print the silhouette scores DataFrame
print(new_pca)
# Out:
# For Cluster = 3
# <style type="text/css">
# </style>
# <table id="T_e2712" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e2712_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_e2712_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_e2712_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_e2712_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_e2712_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_e2712_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e2712_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_e2712_row0_col0" class="data row0 col0" >0.5250</td>
#       <td id="T_e2712_row0_col1" class="data row0 col1" >675.3120</td>
# ...

# %%
from pycaret.datasets import get_data
from pycaret.clustering import *
import pandas as pd
from sklearn.metrics import silhouette_score
from sklearn.metrics import calinski_harabasz_score
from sklearn.metrics import davies_bouldin_score

# Load the dataset
cancer = get_data('cancer', verbose=False)

# Setup the environment
setup(data=cancer, transformation = True, normalize = True,
      normalize_method = 'zscore', transformation_method = 'yeo-johnson', verbose=False)

# Initialize an empty DataFrame to store the silhouette scores
trans_and_norm = pd.DataFrame(columns=['Num Clusters', 'Silhouette Score'])

# Iterate over different numbers of clusters
for num_clusters in [3, 4, 5]:
    print(f"For Cluster = {num_clusters}")

    # Create the KMeans clustering model
    kmeans_model = create_model('kmeans', num_clusters=num_clusters)

    # Get cluster labels
    labels = kmeans_model.labels_

    # Compute silhouette score
    silhouette_score_value = silhouette_score(cancer, labels)
    calinski_harabasz_score_value = calinski_harabasz_score(cancer, labels)
    davies_bouldin_score_value=davies_bouldin_score(cancer,labels)
    # Store the silhouette score in the DataFrame
    trans_and_norm  = trans_and_norm.append({'Num Clusters': num_clusters, 'Silhouette Score': silhouette_score_value, 'Calinski-Score':calinski_harabasz_score_value,'Davies-Bouldin':davies_bouldin_score_value}, ignore_index=True)
    new_trans_and_norm= trans_and_norm.set_index('Num Clusters')
# Print the silhouette scores DataFrame
print(new_trans_and_norm )
# Out:
# For Cluster = 3
# <style type="text/css">
# </style>
# <table id="T_48db3" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_48db3_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_48db3_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_48db3_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_48db3_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_48db3_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_48db3_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_48db3_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_48db3_row0_col0" class="data row0 col0" >0.4984</td>
#       <td id="T_48db3_row0_col1" class="data row0 col1" >786.5620</td>
# ...

# %%
from pycaret.datasets import get_data
from pycaret.clustering import *
import pandas as pd
from sklearn.metrics import silhouette_score
from sklearn.metrics import calinski_harabasz_score
from sklearn.metrics import davies_bouldin_score

# Load the dataset
cancer = get_data('cancer', verbose=False)

# Setup the environment
setup(data=cancer, transformation = True, normalize = True,
      normalize_method = 'zscore', transformation_method = 'yeo-johnson', verbose=False)

# Initialize an empty DataFrame to store the silhouette scores
trans_and_norm_and_pca = pd.DataFrame(columns=['Num Clusters', 'Silhouette Score'])

# Iterate over different numbers of clusters
for num_clusters in [3, 4, 5]:
    print(f"For Cluster = {num_clusters}")

    # Create the KMeans clustering model
    kmeans_model = create_model('kmeans', num_clusters=num_clusters)

    # Get cluster labels
    labels = kmeans_model.labels_

    # Compute silhouette score
    silhouette_score_value = silhouette_score(cancer, labels)
    calinski_harabasz_score_value = calinski_harabasz_score(cancer, labels)
    davies_bouldin_score_value=davies_bouldin_score(cancer,labels)
    # Store the silhouette score in the DataFrame
    trans_and_norm_and_pca = trans_and_norm_and_pca.append({'Num Clusters': num_clusters, 'Silhouette Score': silhouette_score_value, 'Calinski-Score':calinski_harabasz_score_value,'Davies-Bouldin':davies_bouldin_score_value}, ignore_index=True)
    new_trans_and_norm_and_pca=trans_and_norm_and_pca.set_index('Num Clusters')
# Print the silhouette scores DataFrame
print(new_trans_and_norm_and_pca)
# Out:
# For Cluster = 3
# <style type="text/css">
# </style>
# <table id="T_ed535" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ed535_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_ed535_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_ed535_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_ed535_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_ed535_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_ed535_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ed535_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_ed535_row0_col0" class="data row0 col0" >0.4984</td>
#       <td id="T_ed535_row0_col1" class="data row0 col1" >786.5620</td>
# ...

# %%
df=pd.concat([new_no_pre,new_normal,new_transform,new_pca,new_trans_and_norm,new_trans_and_norm_and_pca],axis=1)

# %%
df
df.to_csv("kmeans.csv")

# %%
# Out:
#    A  B New_Column
# 0  1  4        NaN
# 1  2  5        NaN
# 2  3  6        NaN

# %%
from pycaret.datasets import get_data
from pycaret.clustering import *
import pandas as pd
from sklearn.cluster import MeanShift
from sklearn.metrics import silhouette_score
from sklearn.metrics import calinski_harabasz_score
from sklearn.metrics import davies_bouldin_score

# Load the dataset
cancer = get_data('cancer', verbose=False)

# Setup the environment
setup(data=cancer, verbose=False)

# Initialize an empty DataFrame to store the silhouette scores
no_pre = pd.DataFrame(columns=['Num Clusters', 'Silhouette Score'])

# Iterate over different numbers of clusters
for num_clusters in [3, 4, 5]:
    print(f"For Cluster = {num_clusters}")

    # Create the KMeans clustering model
    meanshift_model = create_model('meanshift', num_clusters=num_clusters)

    # Get cluster labels
    labels = meanshift_model.labels_

    # Compute silhouette score
    silhouette_score_value = silhouette_score(cancer, labels)
    calinski_harabasz_score_value = calinski_harabasz_score(cancer, labels)
    davies_bouldin_score_value=davies_bouldin_score(cancer,labels)
    # Store the silhouette score in the DataFrame
    no_pre = no_pre.append({'Num Clusters': num_clusters, 'Silhouette Score': silhouette_score_value, 'Calinski-Score':calinski_harabasz_score_value,'Davies-Bouldin':davies_bouldin_score_value}, ignore_index=True)
    new_no_pre=no_pre.set_index('Num Clusters')
# Print the silhouette scores DataFrame
print(new_no_pre)
# Out:
# For Cluster = 3
# <style type="text/css">
# </style>
# <table id="T_8d63c" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8d63c_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_8d63c_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_8d63c_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_8d63c_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_8d63c_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_8d63c_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8d63c_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_8d63c_row0_col0" class="data row0 col0" >0.4759</td>
#       <td id="T_8d63c_row0_col1" class="data row0 col1" >124.3155</td>
# ...

# %%
from pycaret.datasets import get_data
from pycaret.clustering import *
import pandas as pd
from sklearn.metrics import silhouette_score
from sklearn.metrics import calinski_harabasz_score
from sklearn.metrics import davies_bouldin_score

# Load the dataset
cancer = get_data('cancer', verbose=False)

# Setup the environment
setup(data=cancer,normalize = True, normalize_method = 'zscore', verbose=False)

# Initialize an empty DataFrame to store the silhouette scores
normal = pd.DataFrame(columns=['Num Clusters', 'Silhouette Score'])

# Iterate over different numbers of clusters
for num_clusters in [3, 4, 5]:
    print(f"For Cluster = {num_clusters}")

    # Create the KMeans clustering model
    meanshift_model = create_model('meanshift', num_clusters=num_clusters)

    # Get cluster labels
    labels = meanshift_model.labels_

    # Compute silhouette score
    silhouette_score_value = silhouette_score(cancer, labels)
    calinski_harabasz_score_value = calinski_harabasz_score(cancer, labels)
    davies_bouldin_score_value=davies_bouldin_score(cancer,labels)
    # Store the silhouette score in the DataFrame
    normal = normal.append({'Num Clusters': num_clusters, 'Silhouette Score': silhouette_score_value, 'Calinski-Score':calinski_harabasz_score_value,'Davies-Bouldin':davies_bouldin_score_value}, ignore_index=True)
    new_normal=normal.set_index('Num Clusters')
# Print the silhouette scores DataFrame
print(new_normal)
# Out:
# For Cluster = 3
# <style type="text/css">
# </style>
# <table id="T_4bd32" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4bd32_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_4bd32_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_4bd32_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_4bd32_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_4bd32_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_4bd32_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4bd32_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_4bd32_row0_col0" class="data row0 col0" >0.4260</td>
#       <td id="T_4bd32_row0_col1" class="data row0 col1" >104.4535</td>
# ...

# %%
from pycaret.datasets import get_data
from pycaret.clustering import *
import pandas as pd
from sklearn.metrics import silhouette_score
from sklearn.metrics import calinski_harabasz_score
from sklearn.metrics import davies_bouldin_score

# Load the dataset
cancer = get_data('cancer', verbose=False)

# Setup the environment
setup(data=cancer,transformation = True, transformation_method = 'yeo-johnson', verbose=False)

# Initialize an empty DataFrame to store the silhouette scores
transform = pd.DataFrame(columns=['Num Clusters', 'Silhouette Score'])

# Iterate over different numbers of clusters
for num_clusters in [3, 4, 5]:
    print(f"For Cluster = {num_clusters}")

    # Create the KMeans clustering model
    meanshift_model = create_model('meanshift', num_clusters=num_clusters)

    # Get cluster labels
    labels = meanshift_model.labels_

    # Compute silhouette score
    silhouette_score_value = silhouette_score(cancer, labels)
    calinski_harabasz_score_value = calinski_harabasz_score(cancer, labels)
    davies_bouldin_score_value=davies_bouldin_score(cancer,labels)
    # Store the silhouette score in the DataFrame
    transform = transform.append({'Num Clusters': num_clusters, 'Silhouette Score': silhouette_score_value, 'Calinski-Score':calinski_harabasz_score_value,'Davies-Bouldin':davies_bouldin_score_value}, ignore_index=True)
    new_transform=transform.set_index('Num Clusters')
# Print the silhouette scores DataFrame
print(new_transform)
# Out:
# For Cluster = 3
# <style type="text/css">
# </style>
# <table id="T_ad58c" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ad58c_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_ad58c_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_ad58c_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_ad58c_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_ad58c_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_ad58c_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ad58c_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_ad58c_row0_col0" class="data row0 col0" >0.4633</td>
#       <td id="T_ad58c_row0_col1" class="data row0 col1" >948.9463</td>
# ...

# %%
from pycaret.datasets import get_data
from pycaret.clustering import *
import pandas as pd
from sklearn.metrics import silhouette_score
from sklearn.metrics import calinski_harabasz_score
from sklearn.metrics import davies_bouldin_score

# Load the dataset
cancer = get_data('cancer', verbose=False)

# Setup the environment
setup(data=cancer,pca = True, pca_method = 'linear', verbose=False)

# Initialize an empty DataFrame to store the silhouette scores
pca = pd.DataFrame(columns=['Num Clusters', 'Silhouette Score'])

# Iterate over different numbers of clusters
for num_clusters in [3, 4, 5]:
    print(f"For Cluster = {num_clusters}")

    # Create the KMeans clustering model
    meanshift_model = create_model('meanshift', num_clusters=num_clusters)

    # Get cluster labels
    labels = meanshift_model.labels_

    # Compute silhouette score
    silhouette_score_value = silhouette_score(cancer, labels)
    calinski_harabasz_score_value = calinski_harabasz_score(cancer, labels)
    davies_bouldin_score_value=davies_bouldin_score(cancer,labels)
    # Store the silhouette score in the DataFrame
    pca = pca.append({'Num Clusters': num_clusters, 'Silhouette Score': silhouette_score_value, 'Calinski-Score':calinski_harabasz_score_value,'Davies-Bouldin':davies_bouldin_score_value}, ignore_index=True)
    new_pca=pca.set_index('Num Clusters')
# Print the silhouette scores DataFrame
print(new_pca)
# Out:
# For Cluster = 3
# <style type="text/css">
# </style>
# <table id="T_0d0db" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0d0db_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_0d0db_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_0d0db_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_0d0db_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_0d0db_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_0d0db_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0d0db_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_0d0db_row0_col0" class="data row0 col0" >0.4759</td>
#       <td id="T_0d0db_row0_col1" class="data row0 col1" >124.3155</td>
# ...

# %%
from pycaret.datasets import get_data
from pycaret.clustering import *
import pandas as pd
from sklearn.metrics import silhouette_score
from sklearn.metrics import calinski_harabasz_score
from sklearn.metrics import davies_bouldin_score

# Load the dataset
cancer = get_data('cancer', verbose=False)

# Setup the environment
setup(data=cancer, transformation = True, normalize = True,
      normalize_method = 'zscore', transformation_method = 'yeo-johnson', verbose=False)

# Initialize an empty DataFrame to store the silhouette scores
trans_and_norm = pd.DataFrame(columns=['Num Clusters', 'Silhouette Score'])

# Iterate over different numbers of clusters
for num_clusters in [3, 4, 5]:
    print(f"For Cluster = {num_clusters}")

    # Create the KMeans clustering model
    meanshift_model = create_model('meanshift', num_clusters=num_clusters)

    # Get cluster labels
    labels = meanshift_model.labels_

    # Compute silhouette score
    silhouette_score_value = silhouette_score(cancer, labels)
    calinski_harabasz_score_value = calinski_harabasz_score(cancer, labels)
    davies_bouldin_score_value=davies_bouldin_score(cancer,labels)
    # Store the silhouette score in the DataFrame
    trans_and_norm  = trans_and_norm.append({'Num Clusters': num_clusters, 'Silhouette Score': silhouette_score_value, 'Calinski-Score':calinski_harabasz_score_value,'Davies-Bouldin':davies_bouldin_score_value}, ignore_index=True)
    new_trans_and_norm= trans_and_norm.set_index('Num Clusters')
# Print the silhouette scores DataFrame
print(new_trans_and_norm )
# Out:
# For Cluster = 3
# <style type="text/css">
# </style>
# <table id="T_20e5c" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_20e5c_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_20e5c_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_20e5c_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_20e5c_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_20e5c_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_20e5c_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_20e5c_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_20e5c_row0_col0" class="data row0 col0" >0.4515</td>
#       <td id="T_20e5c_row0_col1" class="data row0 col1" >596.4111</td>
# ...

# %%
from pycaret.datasets import get_data
from pycaret.clustering import *
import pandas as pd
from sklearn.metrics import silhouette_score
from sklearn.metrics import calinski_harabasz_score
from sklearn.metrics import davies_bouldin_score

# Load the dataset
cancer = get_data('cancer', verbose=False)

# Setup the environment
setup(data=cancer, transformation = True, normalize = True,
      normalize_method = 'zscore', transformation_method = 'yeo-johnson', verbose=False)

# Initialize an empty DataFrame to store the silhouette scores
trans_and_norm_and_pca = pd.DataFrame(columns=['Num Clusters', 'Silhouette Score'])

# Iterate over different numbers of clusters
for num_clusters in [3, 4, 5]:
    print(f"For Cluster = {num_clusters}")

    # Create the KMeans clustering model
    meanshift_model = create_model('meanshift', num_clusters=num_clusters)

    # Get cluster labels
    labels = meanshift_model.labels_

    # Compute silhouette score
    silhouette_score_value = silhouette_score(cancer, labels)
    calinski_harabasz_score_value = calinski_harabasz_score(cancer, labels)
    davies_bouldin_score_value=davies_bouldin_score(cancer,labels)
    # Store the silhouette score in the DataFrame
    trans_and_norm_and_pca = trans_and_norm_and_pca.append({'Num Clusters': num_clusters, 'Silhouette Score': silhouette_score_value, 'Calinski-Score':calinski_harabasz_score_value,'Davies-Bouldin':davies_bouldin_score_value}, ignore_index=True)
    new_trans_and_norm_and_pca=trans_and_norm_and_pca.set_index('Num Clusters')
# Print the silhouette scores DataFrame
print(new_trans_and_norm_and_pca)
# Out:
# For Cluster = 3
# <style type="text/css">
# </style>
# <table id="T_478c1" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_478c1_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_478c1_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_478c1_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_478c1_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_478c1_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_478c1_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_478c1_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_478c1_row0_col0" class="data row0 col0" >0.4515</td>
#       <td id="T_478c1_row0_col1" class="data row0 col1" >596.4111</td>
# ...

# %%
df=pd.concat([new_no_pre,new_normal,new_transform,new_pca,new_trans_and_norm,new_trans_and_norm_and_pca],axis=1)

# %%
df
df.to_csv("meanshift.csv")

# %%
from pycaret.datasets import get_data
from pycaret.clustering import *
import pandas as pd
# from sklearn.cluster import birch
from sklearn.metrics import silhouette_score
from sklearn.metrics import calinski_harabasz_score
from sklearn.metrics import davies_bouldin_score

# Load the dataset
cancer = get_data('cancer', verbose=False)

# Setup the environment
setup(data=cancer, verbose=False)

# Initialize an empty DataFrame to store the silhouette scores
no_pre = pd.DataFrame(columns=['Num Clusters', 'Silhouette Score'])

# Iterate over different numbers of clusters
for num_clusters in [3, 4, 5]:
    print(f"For Cluster = {num_clusters}")

    # Create the KMeans clustering model
    birch_model = create_model('birch', num_clusters=num_clusters)

    # Get cluster labels
    labels = birch_model.labels_

    # Compute silhouette score
    silhouette_score_value = silhouette_score(cancer, labels)
    calinski_harabasz_score_value = calinski_harabasz_score(cancer, labels)
    davies_bouldin_score_value=davies_bouldin_score(cancer,labels)
    # Store the silhouette score in the DataFrame
    no_pre = no_pre.append({'Num Clusters': num_clusters, 'Silhouette Score': silhouette_score_value, 'Calinski-Score':calinski_harabasz_score_value,'Davies-Bouldin':davies_bouldin_score_value}, ignore_index=True)
    new_no_pre=no_pre.set_index('Num Clusters')
# Print the silhouette scores DataFrame
print(new_no_pre)
from pycaret.datasets import get_data
from pycaret.clustering import *
import pandas as pd
from sklearn.metrics import silhouette_score
from sklearn.metrics import calinski_harabasz_score
from sklearn.metrics import davies_bouldin_score

# Load the dataset
cancer = get_data('cancer', verbose=False)

# Setup the environment
setup(data=cancer,normalize = True, normalize_method = 'zscore', verbose=False)

# Initialize an empty DataFrame to store the silhouette scores
normal = pd.DataFrame(columns=['Num Clusters', 'Silhouette Score'])

# Iterate over different numbers of clusters
for num_clusters in [3, 4, 5]:
    print(f"For Cluster = {num_clusters}")

    # Create the KMeans clustering model
    birch_model = create_model('birch', num_clusters=num_clusters)

    # Get cluster labels
    labels = birch_model.labels_

    # Compute silhouette score
    silhouette_score_value = silhouette_score(cancer, labels)
    calinski_harabasz_score_value = calinski_harabasz_score(cancer, labels)
    davies_bouldin_score_value=davies_bouldin_score(cancer,labels)
    # Store the silhouette score in the DataFrame
    normal = normal.append({'Num Clusters': num_clusters, 'Silhouette Score': silhouette_score_value, 'Calinski-Score':calinski_harabasz_score_value,'Davies-Bouldin':davies_bouldin_score_value}, ignore_index=True)
    new_normal=normal.set_index('Num Clusters')
# Print the silhouette scores DataFrame
print(new_normal)
from pycaret.datasets import get_data
from pycaret.clustering import *
import pandas as pd
from sklearn.metrics import silhouette_score
from sklearn.metrics import calinski_harabasz_score
from sklearn.metrics import davies_bouldin_score

# Load the dataset
cancer = get_data('cancer', verbose=False)

# Setup the environment
setup(data=cancer,transformation = True, transformation_method = 'yeo-johnson', verbose=False)

# Initialize an empty DataFrame to store the silhouette scores
transform = pd.DataFrame(columns=['Num Clusters', 'Silhouette Score'])

# Iterate over different numbers of clusters
for num_clusters in [3, 4, 5]:
    print(f"For Cluster = {num_clusters}")

    # Create the KMeans clustering model
    birch_model = create_model('birch', num_clusters=num_clusters)

    # Get cluster labels
    labels = birch_model.labels_

    # Compute silhouette score
    silhouette_score_value = silhouette_score(cancer, labels)
    calinski_harabasz_score_value = calinski_harabasz_score(cancer, labels)
    davies_bouldin_score_value=davies_bouldin_score(cancer,labels)
    # Store the silhouette score in the DataFrame
    transform = transform.append({'Num Clusters': num_clusters, 'Silhouette Score': silhouette_score_value, 'Calinski-Score':calinski_harabasz_score_value,'Davies-Bouldin':davies_bouldin_score_value}, ignore_index=True)
    new_transform=transform.set_index('Num Clusters')
# Print the silhouette scores DataFrame
print(new_transform)
from pycaret.datasets import get_data
from pycaret.clustering import *
import pandas as pd
from sklearn.metrics import silhouette_score
from sklearn.metrics import calinski_harabasz_score
from sklearn.metrics import davies_bouldin_score

# Load the dataset
cancer = get_data('cancer', verbose=False)

# Setup the environment
setup(data=cancer,pca = True, pca_method = 'linear', verbose=False)

# Initialize an empty DataFrame to store the silhouette scores
pca = pd.DataFrame(columns=['Num Clusters', 'Silhouette Score'])

# Iterate over different numbers of clusters
for num_clusters in [3, 4, 5]:
    print(f"For Cluster = {num_clusters}")

    # Create the KMeans clustering model
    birch_model = create_model('birch', num_clusters=num_clusters)

    # Get cluster labels
    labels = birch_model.labels_

    # Compute silhouette score
    silhouette_score_value = silhouette_score(cancer, labels)
    calinski_harabasz_score_value = calinski_harabasz_score(cancer, labels)
    davies_bouldin_score_value=davies_bouldin_score(cancer,labels)
    # Store the silhouette score in the DataFrame
    pca = pca.append({'Num Clusters': num_clusters, 'Silhouette Score': silhouette_score_value, 'Calinski-Score':calinski_harabasz_score_value,'Davies-Bouldin':davies_bouldin_score_value}, ignore_index=True)
    new_pca=pca.set_index('Num Clusters')
# Print the silhouette scores DataFrame
print(new_pca)
from pycaret.datasets import get_data
from pycaret.clustering import *
import pandas as pd
from sklearn.metrics import silhouette_score
from sklearn.metrics import calinski_harabasz_score
from sklearn.metrics import davies_bouldin_score

# Load the dataset
cancer = get_data('cancer', verbose=False)

# Setup the environment
setup(data=cancer, transformation = True, normalize = True,
      normalize_method = 'zscore', transformation_method = 'yeo-johnson', verbose=False)

# Initialize an empty DataFrame to store the silhouette scores
trans_and_norm = pd.DataFrame(columns=['Num Clusters', 'Silhouette Score'])

# Iterate over different numbers of clusters
for num_clusters in [3, 4, 5]:
    print(f"For Cluster = {num_clusters}")

    # Create the KMeans clustering model
    birch_model = create_model('birch', num_clusters=num_clusters)

    # Get cluster labels
    labels = birch_model.labels_

    # Compute silhouette score
    silhouette_score_value = silhouette_score(cancer, labels)
    calinski_harabasz_score_value = calinski_harabasz_score(cancer, labels)
    davies_bouldin_score_value=davies_bouldin_score(cancer,labels)
    # Store the silhouette score in the DataFrame
    trans_and_norm  = trans_and_norm.append({'Num Clusters': num_clusters, 'Silhouette Score': silhouette_score_value, 'Calinski-Score':calinski_harabasz_score_value,'Davies-Bouldin':davies_bouldin_score_value}, ignore_index=True)
    new_trans_and_norm= trans_and_norm.set_index('Num Clusters')
# Print the silhouette scores DataFrame
print(new_trans_and_norm )
from pycaret.datasets import get_data
from pycaret.clustering import *
import pandas as pd
from sklearn.metrics import silhouette_score
from sklearn.metrics import calinski_harabasz_score
from sklearn.metrics import davies_bouldin_score

# Load the dataset
cancer = get_data('cancer', verbose=False)

# Setup the environment
setup(data=cancer, transformation = True, normalize = True,
      normalize_method = 'zscore', transformation_method = 'yeo-johnson', verbose=False)

# Initialize an empty DataFrame to store the silhouette scores
trans_and_norm_and_pca = pd.DataFrame(columns=['Num Clusters', 'Silhouette Score'])

# Iterate over different numbers of clusters
for num_clusters in [3, 4, 5]:
    print(f"For Cluster = {num_clusters}")

    # Create the KMeans clustering model
    birch_model = create_model('birch', num_clusters=num_clusters)

    # Get cluster labels
    labels = birch_model.labels_

    # Compute silhouette score
    silhouette_score_value = silhouette_score(cancer, labels)
    calinski_harabasz_score_value = calinski_harabasz_score(cancer, labels)
    davies_bouldin_score_value=davies_bouldin_score(cancer,labels)
    # Store the silhouette score in the DataFrame
    trans_and_norm_and_pca = trans_and_norm_and_pca.append({'Num Clusters': num_clusters, 'Silhouette Score': silhouette_score_value, 'Calinski-Score':calinski_harabasz_score_value,'Davies-Bouldin':davies_bouldin_score_value}, ignore_index=True)
    new_trans_and_norm_and_pca=trans_and_norm_and_pca.set_index('Num Clusters')
# Print the silhouette scores DataFrame
print(new_trans_and_norm_and_pca)
df=pd.concat([new_no_pre,new_normal,new_transform,new_pca,new_trans_and_norm,new_trans_and_norm_and_pca],axis=1)
df
df.to_csv("birch.csv")
# Out:
# For Cluster = 3
# <style type="text/css">
# </style>
# <table id="T_b7d5c" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b7d5c_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_b7d5c_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_b7d5c_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_b7d5c_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_b7d5c_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_b7d5c_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b7d5c_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_b7d5c_row0_col0" class="data row0 col0" >0.5098</td>
#       <td id="T_b7d5c_row0_col1" class="data row0 col1" >623.4898</td>
# ...
